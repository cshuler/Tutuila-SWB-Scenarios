# %%
THings to manifest

- All intact lowland rainorest is preserved   (use Original_LU2_1600.shp)     DONE


- Special management polygons are created     (use Special_mangmet_ares_wetland.shp)
   - MMI, 
   - buffer around wetlands
   - Tafuna Rainforest area
    - aasu forest preserve

- Coastal development reduced and a natural buffer of mangrove forest is created around coastal areas   ??  maybe not
   - do the existing mangrove buffer, but also add in one that pereserves coastal forest or rock araes
    
- increase and consolidataion of agroforest areas   (do with  their location in the expansion model )

- do the stream flood area thing too

# %%
# make the screen bigger!
from IPython.display import display, HTML
display(HTML(data=""" <style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 85%; }
    div#maintoolbar-container { width: 99%; } </style> """))

import numpy as np
import arcpy
import os
from arcpy.sa import *
import pandas as pd
#import gdal
from arcpy import env

arcpy.env.overwriteOutput = True # make sure overwrite files is on

cel_size = 5     # in m   Note that a cell size any smaller than 5 is going to push the files over the 100 mb limit on Github
# projection definition 
sr_project = arcpy.SpatialReference(32702)   # Project dataset into WGS84

# LU Dictionary for later

Lukeys = {400:'Cultivated_Land', 
500:'Agroforest', 
700:'Open_Space', 
800:'Developed_Woodlands', 
1000:'Buildings', 
1000:'Impervious_Surfaces', 
1200:'Mangroves', 
1300:'Exposed_Rock', 
1400:'Grassland', 
1500:'Upland_Scrub', 
1600:'Lowland_Rainforest', 
1700:'Successional_Scrub', 
2100:'Montane_Rainforest', 
-999:"no Data",0:"no Data"}
# Out:
#  <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 85%; }
#     div#maintoolbar-container { width: 99%; } </style>

# %%
GIS_FOLDER = os.path.join('..', 'Raw_GIS_Data')

# path to the grid bound
Grid_shp = os.path.join(GIS_FOLDER, 'grid_bound.shp')

if not os.path.exists(os.path.join('.', 'output//')):
    os.makedirs(os.path.join('.', 'output//'))
                        
if not os.path.exists(os.path.join('.', 'output//Figures//')):
    os.makedirs(os.path.join('.', 'output//Figures//'))
fig_path =  (os.path.join('.', 'output//Figures//'))

if not os.path.exists(os.path.join('.', "WorkSpaces//Scn1")):
    os.makedirs(os.path.join('.', "WorkSpaces//Scn1"))
workspace =  os.path.join('.', "WorkSpaces//Scn1")

# define where the land is too steep to build
steep_land = os.path.join(GIS_FOLDER, 'Slopes', 'steep_land_25deg.shp')

# define where the original low rainforest is to protect 

Forest_preserve_land = os.path.join(GIS_FOLDER, 'LU_Scenarios', 'Original_LU2_1600.shp')

# %%
""" This is the function that selects a land use, then bufferes it, then adds it back to the map. It will be repeated below for multiple nested land uses

    maptoclip is the working version of the land use map, on iteration 1 its the original map, then its the ones that have the buffered areas added in incrementally
    orig_map_to_buffer is the original unadulterated map
    LU_type is the land use getting worked on each iteration
    buffer_dist_m isthe distance of buffering to change, main parameter to modify
"""

def clip_da_use(maptoclip, orig_map_to_buffer, LU_type, buffer_dist_m, steep_land, Forest_preserve_land,  iteration_num):
    
    tempselect = os.path.join(workspace, "temp.shp") 
    tempbuffer = os.path.join(workspace, "temp_buffer.shp")
    buffer_clipped_slopes = os.path.join(workspace, "temp_buffer_clipped.shp")
    clipped_Map = os.path.join(workspace, "LU_shp_erased.shp")
    output_file = os.path.join(workspace, "intermediate_LU_new_{}.shp".format(iteration_num))
    
    # Buffer the features of interest
    arcpy.Select_analysis(orig_map_to_buffer, tempselect, "LBLCLASS = '{}'".format(LU_type))     # select just the LU type desired save as tempselect.shp
    arcpy.Buffer_analysis(tempselect, tempbuffer, buffer_dist_m, dissolve_option="NONE")         # Make a tenporary buffer file of that land use bit 
    arcpy.RepairGeometry_management(tempbuffer)                                                  # fix broken things
    
    # erase out areas where there are large slopes
    arcpy.Erase_analysis(tempbuffer, steep_land,  buffer_clipped_slopes)     
    
    # erase out areas where we are protecting forest
    arcpy.Erase_analysis(tempbuffer, buffer_clipped_slopes,  buffer_clipped_slopes_forest)           
    
    # erase out the new bufferd land area zones
    arcpy.Erase_analysis(maptoclip, buffer_clipped_slopes_forest, clipped_Map)    
    
    # add the new land use type back to the big LU map 
    arcpy.Merge_management([buffer_clipped_slopes_forest, clipped_Map], output_file)

# %%
# hyperparameters
Agroforest_buffer = 55
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU_list =         ['Agroforest',      'Cultivated_Land',     'Developed_Woodlands',      'Open_Space',      'Impervious_Surfaces',      'Buildings']
bufferdist_list = [Agroforest_buffer, Cultivated_Land_buffer, Developed_Woodlands_buffer, Open_Space_buffer, Impervious_Surfaces_buffer, Buildings_buffer]

# %%
# Buffer each land use to expand it respective to the hyperparameters in the cells above

for shed in range(0,33):                          # for each of the watershed clips
    print("Working on shed No. {}..................................................".format(shed))
    
    # Reset the starting map to the new watershed 
    arcpy.CopyFeatures_management(os.path.join(GIS_FOLDER, "Land_use", "Split_into_watersheds", 'Shed_fragments', 'LU_simp3_clipped_{}.shp'.format(shed)), os.path.join(workspace, "intermediate_LU_new_0.shp"))

    Original_Map = os.path.join(workspace, 'intermediate_LU_new_0.shp')    # this is just for shorter syntax on calling the original map

    for iteration_num in range(1,7):        # for each of the land use classes we want to buffer on  (references the lists above)
        maptoclip          = os.path.join(workspace, "intermediate_LU_new_{}.shp".format(iteration_num-1))  # this is where you put in the map from the last iteration
        orig_map_to_buffer = Original_Map
        LU_type            = LU_list[iteration_num-1]
        buffer_dist_m      = bufferdist_list[iteration_num-1]
        print("now buffering {}".format(LU_type))

        clip_da_use(maptoclip, orig_map_to_buffer, LU_type, buffer_dist_m, steep_land, iteration_num)   # run the clip buffer erase merge function

    # trim off any excess that has spilled out of the watershed
    arcpy.Clip_analysis(os.path.join(workspace, "intermediate_LU_new_6.shp"), Original_Map, os.path.join(workspace, "Finished_LU_{}.shp".format(shed)))

# Merge all the litte buffered watershed ones together
# Create 99, the final merged set
arcpy.CopyFeatures_management(os.path.join(workspace, 'Finished_LU_0.shp'), os.path.join(workspace, "Finished_LU_99.shp"))
for p in range(1,33):
    arcpy.Append_management(os.path.join(workspace, 'Finished_LU_{}.shp'.format(p)), os.path.join(workspace, "Finished_LU_99.shp"))  #agregate function
# Out:
# Working on shed No. 0..................................................
# now buffering Agroforest
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b3455c89c7f7> in <module>()
#      16         print("now buffering {}".format(LU_type))
#      17
# ---> 18         clip_da_use(maptoclip, orig_map_to_buffer, LU_type, buffer_dist_m, steep_land, iteration_num)   # run the clip buffer erase merge function
#      19
#      20     # trim off any excess that has spilled out of the watershed
#
# TypeError: clip_da_use() missing 1 required positional argument: 'iteration_num'

# %%
# Step added in to merge the new Aasu land use with the new bufferred land use file
# erase out new area from buffered islandwide land use
arcpy.Erase_analysis(os.path.join(workspace, "Finished_LU_99.shp"), os.path.join(GIS_FOLDER, 'LU_Scenarios', 'New_land_use500m.shp'),  os.path.join(workspace, "temp2.shp"))              
print("success")
# add the new land use  back to the big LU map 
arcpy.Merge_management([os.path.join(workspace, "temp2.shp"), os.path.join(GIS_FOLDER, 'LU_Scenarios', 'New_land_use500m.shp')], os.path.join(workspace, "Finished_LU_99.shp"))
# Out:
# success
# <Result '.\\WorkSpaces\\\\Scn1\\Finished_LU_99.shp'>

# %%
# add in efects of sea level rise based on 3 ft scenario (see references folder in github) 
# in short this finds ares affected by 3ft SLR then turns them from other land uses to mangroves except if they were originally coastal bare rock, in which case it turns them back to bare rock
  
# first create a shapefile of wherer there is unconsolidated shore overlapped by SLR

# buffer the coastline by 250 m
arcpy.Buffer_analysis(os.path.join(GIS_FOLDER, "SLR", "Present_day_coastline.shp"), os.path.join(workspace, "temp_buffer2.shp"), 250, dissolve_option="ALL") 
# select the rocky areas from the orignal LU map
arcpy.Select_analysis(os.path.join(GIS_FOLDER, 'Land_use', 'Split_into_watersheds', 'LU_Big_simp_3.shp'), os.path.join(workspace, "temp2.shp"), '"LBLCLASS" = \'Exposed_Rock\'')
# get only the rock coastal areas 
arcpy.Intersect_analysis([os.path.join(workspace, "temp2.shp"), os.path.join(workspace, "temp_buffer2.shp")], os.path.join(workspace, "temp_Coastal_ROck.shp"), "ALL")

# Now take the final result from the big LU buffering process and clip out  ALLL areas where SLR will impact and turn them into mangroves

arcpy.Erase_analysis(os.path.join(workspace, "Finished_LU_99.shp"), os.path.join(GIS_FOLDER, 'SLR', "AS_Tutuila_SLR_3ft_man_Dissolve.shp"), os.path.join(workspace, "tempSLR.shp"))
# add the new mangrove areas back to the big LU map 
arcpy.Merge_management([os.path.join(workspace, "tempSLR.shp"), os.path.join(GIS_FOLDER, 'SLR', "AS_Tutuila_SLR_3ft_man_Dissolve.shp")], os.path.join(workspace, "Finished_LU_99.shp"))

# Finally clip out the new mangrove areas that were on top of coastal rock and make them coasta rock once again.
arcpy.Erase_analysis(os.path.join(workspace, "Finished_LU_99.shp"), os.path.join(workspace, "temp_Coastal_ROck.shp"), os.path.join(workspace, "tempRock2wholeI.shp"))
# add the new mangrove areas back to the big LU map 
arcpy.Merge_management([os.path.join(workspace, "tempRock2wholeI.shp"), os.path.join(workspace, "temp_Coastal_ROck.shp")], os.path.join(workspace, "Finished_LU_99.shp"))
# Out:
# <Result '.\\WorkSpaces\\\\Scn1\\Finished_LU_99.shp'>

# %%
# Ultimately this should be run on the re-merged together shapefile of all watersheds

# This converts the original and the new coverage to rasters to run the percentage calculation stats

# just give a link to the shapefile of major watersheds
Origlandusefile = os.path.join(GIS_FOLDER, 'Land_use', 'Split_into_watersheds', 'LU_Big_simp_3.shp')
#  Merge in the grid boundary into the finished shapefile to create accurate grid coverage 
arcpy.Erase_analysis(Grid_shp, os.path.join(workspace, "Finished_LU_99.shp"),  os.path.join(workspace, 'LU_shp_bound.shp'))
arcpy.Merge_management([os.path.join(workspace, 'LU_shp_bound.shp'), os.path.join(workspace, "Finished_LU_99.shp")], os.path.join(workspace, 'LU_shp_ready.shp'))

# convert to raster.asc
arcpy.PolygonToRaster_conversion(os.path.join(workspace, 'LU_shp_ready.shp'), "LU2", os.path.join(workspace, "LU_raster"), cell_assignment="MAXIMUM_AREA",  cellsize=cel_size)
arcpy.RasterToASCII_conversion(os.path.join(workspace, "LU_raster"), os.path.join(workspace, "new_LU_grid.asc"))

# this deos the same with the original one for comparison
#  Merge in the grid bound into the shapefile to create accurate grid coverage 
arcpy.Erase_analysis(Grid_shp, Origlandusefile,  os.path.join(workspace, 'LU_shp_bound.shp'))
arcpy.Merge_management([os.path.join(workspace, 'LU_shp_bound.shp'), Origlandusefile], os.path.join(workspace, 'LU_shp_ready.shp'))

# convert to raster.asc
arcpy.PolygonToRaster_conversion(os.path.join(workspace, 'LU_shp_ready.shp'), "LU2", os.path.join(workspace, "LU_raster"), cell_assignment="MAXIMUM_AREA",  cellsize=cel_size)
arcpy.RasterToASCII_conversion(os.path.join(workspace, "LU_raster"), os.path.join(workspace, "original_LU_grid.asc"))

arr = arcpy.RasterToNumPyArray(os.path.join(workspace, "original_LU_grid.asc"),  nodata_to_value=-999)
unique, counts = np.unique(arr, return_counts=True)
arr_stats_original = np.asarray((unique, counts)).T

arr = arcpy.RasterToNumPyArray(os.path.join(workspace, "new_LU_grid.asc"),  nodata_to_value=-999)
unique, counts = np.unique(arr, return_counts=True)
arr_stats_new = np.asarray((unique, counts)).T

# this takes the cell counts for each land use type in the new and old rasters and compares them percentage-wise
new_dic = {}; old_dic = {}
for i in arr_stats_new: 
    new_dic[i[0]] = i[1]
for i in arr_stats_original: 
    old_dic[i[0]] = i[1]
    
for i in old_dic:
    try:     
        oabs = old_dic[i]
        nabs = new_dic[i]
        pctchange = ((nabs/oabs)-1)*100
        print("LU type_{:.0f}, {}, is {:.2f}% different".format(i, Lukeys[i], pctchange))
    except:
        print("LU {} does not exist in one coverage".format(i))
# Out:
# LU -999 does not exist in one coverage
# LU type_0, no Data, is 0.08% different
# LU type_400, Cultivated_Land, is 7.11% different
# LU type_500, Agroforest, is 43.88% different
# LU type_700, Open_Space, is -12.89% different
# LU type_800, Developed_Woodlands, is -62.80% different
# LU type_1000, Impervious_Surfaces, is 96.45% different
# LU type_1200, Mangroves, is 219.24% different
# LU type_1300, Exposed_Rock, is -30.79% different
# LU type_1400, Grassland, is -46.72% different
# LU type_1500, Upland_Scrub, is -9.91% different
# LU type_1600, Lowland_Rainforest, is -7.15% different
# LU type_1700, Successional_Scrub, is -34.05% different
# LU type_2100, Montane_Rainforest, is -0.63% different

# %%
# IMPORTANT! 
### When pushing to github uncoment and run this cell, this file is over 100 mb

    
# delete the Aggregated shapefile to push to GitHub (>100 mb) uncheck this to get the shapefile back

#arcpy.Delete_management(os.path.join(workspace, "Finished_LU_99.shp"))
# Out:
# <Result 'true'>

# %%
LOG



# hyperparameters
Agroforest_buffer = 50
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 7.12% different
LU type_500, Agroforest, is 39.27% different
LU type_700, Open_Space, is -12.84% different
LU type_800, Developed_Woodlands, is -62.74% different
LU type_1000, Impervious_Surfaces, is 96.47% different
LU type_1200, Mangroves, is 287.43% different
LU type_1300, Exposed_Rock, is -60.66% different
LU type_1400, Grassland, is -45.35% different
LU type_1500, Upland_Scrub, is -9.57% different
LU type_1600, Lowland_Rainforest, is -6.76% different
LU type_1700, Successional_Scrub, is -33.11% different
LU type_2100, Montane_Rainforest, is -0.63% different

############## Here we sub in mangroves for all SLR areas


# this one looks pretty good!
# hyperparameters
Agroforest_buffer = 300
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 7.35% different
LU type_500, Agroforest, is 43.34% different
LU type_700, Open_Space, is -11.63% different
LU type_800, Developed_Woodlands, is -61.26% different
LU type_1000, Impervious_Surfaces, is 98.70% different
LU type_1200, Mangroves, is -53.94% different
LU type_1300, Exposed_Rock, is -43.46% different
LU type_1400, Grassland, is -44.91% different
LU type_1500, Upland_Scrub, is -8.64% different
LU type_1600, Lowland_Rainforest, is -6.63% different
LU type_1700, Successional_Scrub, is -33.05% different
LU type_2100, Montane_Rainforest, is -0.63% different



Agroforest_buffer = 30
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 7.35% different
LU type_500, Agroforest, is 18.51% different
LU type_700, Open_Space, is -11.63% different
LU type_800, Developed_Woodlands, is -61.25% different
LU type_1000, Impervious_Surfaces, is 98.70% different
LU type_1200, Mangroves, is -37.16% different
LU type_1300, Exposed_Rock, is -38.68% different
LU type_1400, Grassland, is -38.40% different
LU type_1500, Upland_Scrub, is -6.89% different
LU type_1600, Lowland_Rainforest, is -4.87% different
LU type_1700, Successional_Scrub, is -28.48% different
LU type_2100, Montane_Rainforest, is -0.48% different



# hyperparameters
Agroforest_buffer = 300
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 7.36% different
LU type_500, Agroforest, is 181.09% different
LU type_700, Open_Space, is -11.64% different
LU type_800, Developed_Woodlands, is -61.26% different
LU type_1000, Impervious_Surfaces, is 98.70% different
LU type_1200, Mangroves, is -99.98% different
LU type_1300, Exposed_Rock, is -69.68% different
LU type_1400, Grassland, is -66.16% different
LU type_1500, Upland_Scrub, is -13.91% different
LU type_1600, Lowland_Rainforest, is -17.55% different
LU type_1700, Successional_Scrub, is -47.51% different
LU type_2100, Montane_Rainforest, is -1.52% different


# hyperparameters
Agroforest_buffer = 10
Cultivated_Land_buffer = 4
Developed_Woodlands_buffer = 5.5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 11.95% different
LU type_500, Agroforest, is -15.88% different
LU type_700, Open_Space, is -11.62% different
LU type_800, Developed_Woodlands, is -59.93% different
LU type_1000, Impervious_Surfaces, is 98.67% different
LU type_1200, Mangroves, is -18.95% different
LU type_1300, Exposed_Rock, is -35.87% different
LU type_1400, Grassland, is -27.71% different
LU type_1500, Upland_Scrub, is -4.92% different
LU type_1600, Lowland_Rainforest, is -3.04% different
LU type_1700, Successional_Scrub, is -21.88% different
LU type_2100, Montane_Rainforest, is -0.18% different






########################## above here include Aasu changed LU as well


# hyperparameters
Agroforest_buffer = 10
Cultivated_Land_buffer = 5
Developed_Woodlands_buffer = 5.5
Open_Space_buffer = 5.5
Impervious_Surfaces_buffer = 6.5 
Buildings_buffer = 5.5

LU type_-999, no Data, is 0.00% different
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 11.88% different
LU type_500, Agroforest, is -23.50% different
LU type_700, Open_Space, is -15.81% different
LU type_800, Developed_Woodlands, is -66.65% different
LU type_1000, Impervious_Surfaces, is 103.81% different
LU type_1200, Mangroves, is -19.11% different
LU type_1300, Exposed_Rock, is -36.11% different
LU type_1400, Grassland, is -30.07% different
LU type_1500, Upland_Scrub, is -4.94% different
LU type_1600, Lowland_Rainforest, is -2.00% different
LU type_1700, Successional_Scrub, is -22.25% different
LU type_2100, Montane_Rainforest, is -0.19% different





# hyperparameters
Agroforest_buffer = 5.5
Cultivated_Land_buffer = 4.5
Developed_Woodlands_buffer = 5
Open_Space_buffer = 5
Impervious_Surfaces_buffer = 6 
Buildings_buffer = 5

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 11.38% different
LU type_500, Agroforest, is -28.11% different
LU type_700, Open_Space, is -14.18% different
LU type_800, Developed_Woodlands, is -64.16% different
LU type_1000, Impervious_Surfaces, is 97.36% different
LU type_1200, Mangroves, is -14.67% different
LU type_1300, Exposed_Rock, is -35.08% different
LU type_1400, Grassland, is -24.74% different
LU type_1500, Upland_Scrub, is -4.43% different
LU type_1600, Lowland_Rainforest, is -1.51% different
LU type_1700, Successional_Scrub, is -18.83% different
LU type_2100, Montane_Rainforest, is -0.12% different


# hyperparameters
Agroforest_buffer = 5
Cultivated_Land_buffer = 4
Developed_Woodlands_buffer = 4
Open_Space_buffer = 4
Impervious_Surfaces_buffer = 5 
Buildings_buffer = 4

LU type_-999, no Data, is 0.00% different
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 12.70% different
LU type_500, Agroforest, is -25.34% different
LU type_700, Open_Space, is -10.89% different
LU type_800, Developed_Woodlands, is -57.77% different
LU type_1000, Impervious_Surfaces, is 83.00% different
LU type_1200, Mangroves, is -13.13% different
LU type_1300, Exposed_Rock, is -33.77% different
LU type_1400, Grassland, is -22.41% different
LU type_1500, Upland_Scrub, is -4.17% different
LU type_1600, Lowland_Rainforest, is -1.37% different
LU type_1700, Successional_Scrub, is -17.57% different
LU type_2100, Montane_Rainforest, is -0.10% different


# hyperparameters
Agroforest_buffer = 4
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 3
Open_Space_buffer = 3
Impervious_Surfaces_buffer = 4 
Buildings_buffer = 3

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 11.00% different
LU type_500, Agroforest, is -20.28% different
LU type_700, Open_Space, is -8.24% different
LU type_800, Developed_Woodlands, is -49.34% different
LU type_1000, Impervious_Surfaces, is 67.36% different
LU type_1200, Mangroves, is -10.90% different
LU type_1300, Exposed_Rock, is -32.22% different
LU type_1400, Grassland, is -18.37% different
LU type_1500, Upland_Scrub, is -3.80% different
LU type_1600, Lowland_Rainforest, is -1.11% different
LU type_1700, Successional_Scrub, is -15.23% different
LU type_2100, Montane_Rainforest, is -0.07% different


# hyperparameters
Agroforest_buffer = 4.5
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 3.5
Open_Space_buffer = 2
Impervious_Surfaces_buffer = 3 
Buildings_buffer = 2

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 13.23% different
LU type_500, Agroforest, is -18.06% different
LU type_700, Open_Space, is -6.81% different
LU type_800, Developed_Woodlands, is -32.50% different
LU type_1000, Impervious_Surfaces, is 50.44% different
LU type_1200, Mangroves, is -11.56% different
LU type_1300, Exposed_Rock, is -32.01% different
LU type_1400, Grassland, is -17.87% different
LU type_1500, Upland_Scrub, is -3.65% different
LU type_1600, Lowland_Rainforest, is -1.12% different
LU type_1700, Successional_Scrub, is -15.29% different
LU type_2100, Montane_Rainforest, is -0.08% different


# hyperparameters
Agroforest_buffer = 4.5
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 3.5
Open_Space_buffer = 2
Impervious_Surfaces_buffer = 3 
Buildings_buffer = 2

LU -999 does not exist in one coverage
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 7.07% different
LU type_500, Agroforest, is -11.75% different
LU type_700, Open_Space, is -6.83% different
LU type_800, Developed_Woodlands, is -34.43% different
LU type_1000, Impervious_Surfaces, is 50.43% different
LU type_1200, Mangroves, is -10.54% different
LU type_1300, Exposed_Rock, is -31.50% different
LU type_1400, Grassland, is -15.75% different
LU type_1500, Upland_Scrub, is -3.58% different
LU type_1600, Lowland_Rainforest, is -0.96% different
LU type_1700, Successional_Scrub, is -13.93% different
LU type_2100, Montane_Rainforest, is -0.08% different


# hyperparameters
Agroforest_buffer = 5
Cultivated_Land_buffer = 3
Developed_Woodlands_buffer = 3
Open_Space_buffer = 1
Impervious_Surfaces_buffer = 0.75 
Buildings_buffer = 0.75

LU type_-999, no Data, is 0.00% different
LU type_0, no Data, is 0.14% different
LU type_400, Cultivated_Land, is 17.48% different
LU type_500, Agroforest, is -14.61% different
LU type_700, Open_Space, is 4.34% different
LU type_800, Developed_Woodlands, is -7.78% different
LU type_1000, Impervious_Surfaces, is 15.12% different
LU type_1200, Mangroves, is -11.23% different
LU type_1300, Exposed_Rock, is -30.66% different
LU type_1400, Grassland, is -15.44% different
LU type_1500, Upland_Scrub, is -3.27% different
LU type_1600, Lowland_Rainforest, is -1.09% different
LU type_1700, Successional_Scrub, is -14.79% different
LU type_2100, Montane_Rainforest, is -0.09% different
